# %% [markdown]
# ### Data Visualization of the Water Data

# %%
# import various python libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('water_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  state_cd  state_name  county_cd       county_nm  year  \
# 0           1         2          40          3              40     4
# 1           2         6  California          1  Alameda County  1985
# 2           3         6  California          1  Alameda County  1990
# 3           4         6  California          1  Alameda County  1995
# 4           5         6  California          1  Alameda County  2000
#
#    Total Population total population of area, in thousand  \
# 0                                              16.00
# 1                                            1195.16
# 2                                            1279.18
# 3                                            1347.70
# 4                                            1443.74
#
#    Public Supply population served by groundwater, in thousand  \
# 0                                              16.00
# 1                                             185.95
# ...

# %%
df= df.drop(columns='Unnamed: 0')

# %%
df=df[1:]

# %%
df.head()
# Out:
#    state_cd  state_name  county_cd       county_nm  year  \
# 1         6  California          1  Alameda County  1985
# 2         6  California          1  Alameda County  1990
# 3         6  California          1  Alameda County  1995
# 4         6  California          1  Alameda County  2000
# 5         6  California          1  Alameda County  2005
#
#    Total Population total population of area, in thousand  \
# 1                                           1195.160
# 2                                           1279.180
# 3                                           1347.700
# 4                                           1443.740
# 5                                           1448.905
#
#    Public Supply population served by groundwater, in thousand  \
# 1                                            185.950
# 2                                            109.370
# 3                                            165.830
# 4                                            152.460
# ...

# %%
for c in df.columns:
    try: 
        df[c].astype(float)
    except:
        print(c)
# Out:
# state_name
# county_nm
# Domestic per capita use, self0supplied, in gallons/person/day

# %%
for val in df['Domestic per capita use, self0supplied, in gallons/person/day']:
    try:
        val = int(val)
    except:
        print(val)
# Out:
# na
# na

# %%
df[df['Domestic per capita use, self0supplied, in gallons/person/day']=='na']
# Out:
#      state_cd  state_name  county_cd             county_nm  year  \
# 262         6  California         75  San Francisco County  1995
# 265         6  California         75  San Francisco County  2010
#
#      Total Population total population of area, in thousand  \
# 262                                            751.500
# 265                                            805.235
#
#      Public Supply population served by groundwater, in thousand  \
# 262                                                0.0
# 265                                                0.0
#
#      Public Supply population served by surface water, in thousand  \
# 262                                            751.500
# 265                                            805.235
#
#      Public Supply total population served, in thousand  \
# 262                                            751.500
# 265                                            805.235
#
# ...

# %%
df['Domestic per capita use, self0supplied, in gallons/person/day'][262] = 0

# %%
df['Domestic per capita use, self0supplied, in gallons/person/day'][262]
# Out:
# 0

# %%
df['Domestic per capita use, self0supplied, in gallons/person/day'][265] = 0
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Domestic per capita use, self0supplied, in gallons/person/day'][265]
# Out:
# 0

# %%
for c in df.columns:
    try: 
        df[c].astype(float)
    except:
        print(c)
# Out:
# state_name
# county_nm

# %%
df.describe()
# Out:
#        state_cd   county_cd         year  \
# count     406.0  406.000000   406.000000
# mean        6.0   58.000000  2000.000000
# std         0.0   33.522648    10.012338
# min         6.0    1.000000  1985.000000
# 25%         6.0   29.000000  1990.000000
# 50%         6.0   58.000000  2000.000000
# 75%         6.0   87.000000  2010.000000
# max         6.0  115.000000  2015.000000
#
#        Total Population total population of area, in thousand  \
# count                                         406.000000
# mean                                          577.782539
# std                                          1331.639182
# min                                             1.110000
# 25%                                            43.733000
# 50%                                           156.061500
# 75%                                           534.941000
# max                                         10170.292000
#
# ...

# %%
df.describe(include='all')
# Out:
#         state_cd  state_name   county_cd       county_nm         year  \
# count      406.0         406  406.000000             406   406.000000
# unique       NaN           1         NaN              58          NaN
# top          NaN  California         NaN  Alameda County          NaN
# freq         NaN         406         NaN               7          NaN
# mean         6.0         NaN   58.000000             NaN  2000.000000
# std          0.0         NaN   33.522648             NaN    10.012338
# min          6.0         NaN    1.000000             NaN  1985.000000
# 25%          6.0         NaN   29.000000             NaN  1990.000000
# 50%          6.0         NaN   58.000000             NaN  2000.000000
# 75%          6.0         NaN   87.000000             NaN  2010.000000
# max          6.0         NaN  115.000000             NaN  2015.000000
#
#         Total Population total population of area, in thousand  \
# count                                          406.000000
# ...

# %%
df.columns
# Out:
# Index(['state_cd', 'state_name', 'county_cd', 'county_nm', 'year',
#        'Total Population total population of area, in thousand',
#        'Public Supply population served by groundwater, in thousand',
#        'Public Supply population served by surface water, in thousand',
#        'Public Supply total population served, in thousand',
#        'Public Supply self0supplied groundwater withdrawals, fresh, in Mgal/d',
#        ...
#        'Hydroelectric Power total offstream surface0water withdrawals in Mgal/d',
#        'Hydroelectric Power power generated by instream use, in gigawatt0hour',
#        'Hydroelectric Power power generated by offstream use, in gigawatt0hour',
#        'Hydroelectric Power total power generated, in gigawatt0hour',
#        'Hydroelectric Power number of instream facilitie',
#        'Hydroelectric Power number of offstream facilitie',
#        'Hydroelectric Power total number of facilitie',
# ...

# %%
df_stat = df.groupby(['county_nm'])['Public Supply total population served, in thousand'].sum()
df_stat
# Out:
# county_nm
# Alameda County             9512.544
# Alpine County                 4.855
# Amador County               167.565
# Butte County               1159.760
# Calaveras County            201.763
# Colusa County                91.301
# Contra Costa County        5906.113
# Del Norte County            131.564
# El Dorado County            945.175
# Fresno County              4932.557
# Glenn County                111.953
# Humboldt County             719.950
# Imperial County             851.855
# Inyo County                  90.239
# Kern County                4391.012
# Kings County                731.858
# Lake County                 285.389
# Lassen County               111.205
# Los Angeles County        62428.917
# Madera County               510.463
# Marin County               1669.454
# Mariposa County              45.064
# Mendocino County            383.018
# Merced County              1165.301
# Modoc County                 30.776
# Mono County                  59.556
# ...

# %%
df_stat.index
# Out:
# Index(['Alameda County', 'Alpine County', 'Amador County', 'Butte County',
#        'Calaveras County', 'Colusa County', 'Contra Costa County',
#        'Del Norte County', 'El Dorado County', 'Fresno County', 'Glenn County',
#        'Humboldt County', 'Imperial County', 'Inyo County', 'Kern County',
#        'Kings County', 'Lake County', 'Lassen County', 'Los Angeles County',
#        'Madera County', 'Marin County', 'Mariposa County', 'Mendocino County',
#        'Merced County', 'Modoc County', 'Mono County', 'Monterey County',
#        'Napa County', 'Nevada County', 'Orange County', 'Placer County',
#        'Plumas County', 'Riverside County', 'Sacramento County',
#        'San Benito County', 'San Bernardino County', 'San Diego County',
#        'San Francisco County', 'San Joaquin County', 'San Luis Obispo County',
#        'San Mateo County', 'Santa Barbara County', 'Santa Clara County',
#        'Santa Cruz County', 'Shasta County', 'Sierra County',
# ...

# %%
df_stat[df_stat==df_stat.max()]
# Out:
# county_nm
# Los Angeles County    62428.917
# Name: Public Supply total population served, in thousand, dtype: float64

# %%
df_stat[df_stat==df_stat.min()]
# Out:
# county_nm
# Alpine County    4.855
# Name: Public Supply total population served, in thousand, dtype: float64

# %%
df.corr('pearson')
# Out:
#                                                     state_cd  county_cd  \
# state_cd                                                 NaN        NaN
# county_cd                                                NaN   1.000000
# year                                                     NaN   0.000000
# Total Population total population of area, in t...       NaN  -0.034381
# Public Supply population served by groundwater,...       NaN  -0.012019
# Public Supply population served by surface wate...       NaN  -0.042790
# Public Supply total population served, in thousand       NaN  -0.035591
# Public Supply self0supplied groundwater withdra...       NaN  -0.008254
# Public Supply self0supplied groundwater withdra...       NaN   0.022069
# Public Supply total self0supplied withdrawals, ...       NaN  -0.007018
# Public Supply self0supplied surface0water withd...       NaN  -0.043247
# Public Supply self0supplied surface0water withd...       NaN        NaN
# ...

# %%
sns.violinplot(df['county_nm'], 
               df['Public Supply population served by groundwater, in thousand'] )
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.show()
